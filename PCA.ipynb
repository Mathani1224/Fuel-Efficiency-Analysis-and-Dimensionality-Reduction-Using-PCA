# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from scipy.stats import zscore

# %%
data=pd.read_csv('auto-mpg.csv')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  modelyear  \
# 0  18.0          8         307.0        130    3504          12.0         70
# 1  15.0          8         350.0        165    3693          11.5         70
# 2  18.0          8         318.0        150    3436          11.0         70
# 3  16.0          8         304.0        150    3433          12.0         70
# 4  17.0          8         302.0        140    3449          10.5         70
#
#    origin                    carname
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.shape
# Out:
# (398, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   modelyear     398 non-null    int64
#  7   origin        398 non-null    int64
#  8   carname       398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#         modelyear      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
temp=pd.DataFrame(data.horsepower.str.isdigit())
temp[temp['horsepower']==False]
# Out:
#      horsepower
# 32        False
# 126       False
# 330       False
# 336       False
# 354       False
# 374       False

# %%
temp=pd.DataFrame(data.horsepower.str.isdigit())
data[temp['horsepower']==False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      modelyear  origin               carname
# 32          71       1            ford pinto
# 126         74       1         ford maverick
# 330         80       2  renault lecar deluxe
# 336         80       1    ford mustang cobra
# 354         81       2           renault 18i
# 374         82       1        amc concord dl

# %%
data=data.drop('carname',axis=1)

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  modelyear  \
# 0  18.0          8         307.0        130    3504          12.0         70
# 1  15.0          8         350.0        165    3693          11.5         70
# 2  18.0          8         318.0        150    3436          11.0         70
# 3  16.0          8         304.0        150    3433          12.0         70
# 4  17.0          8         302.0        140    3449          10.5         70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data=data.replace('?',np.nan)

# %%
data[temp['horsepower']==False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0        NaN    2046          19.0
# 126  21.0          6         200.0        NaN    2875          17.0
# 330  40.9          4          85.0        NaN    1835          17.3
# 336  23.6          4         140.0        NaN    2905          14.3
# 354  34.5          4         100.0        NaN    2320          15.8
# 374  23.0          4         151.0        NaN    3035          20.5
#
#      modelyear  origin
# 32          71       1
# 126         74       1
# 330         80       2
# 336         80       1
# 354         81       2
# 374         82       1

# %%
medianfiller=lambda x:x.fillna(x.median())
data=data.apply(medianfiller,axis=1)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_13900\4207792608.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medianfiller=lambda x:x.fillna(x.median())
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_13900\4207792608.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medianfiller=lambda x:x.fillna(x.median())
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_13900\4207792608.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medianfiller=lambda x:x.fillna(x.median())
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_13900\4207792608.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medianfiller=lambda x:x.fillna(x.median())
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_13900\4207792608.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medianfiller=lambda x:x.fillna(x.median())
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_13900\4207792608.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   medianfiller=lambda x:x.fillna(x.median())

# %%
data['horsepower']=data['horsepower'].astype('float64')

# %%
x=data.drop('mpg',axis=1)
y=data['mpg']

# %%
x.shape
# Out:
# (398, 7)

# %%
x.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  modelyear  \
# 0        8.0         307.0       130.0  3504.0          12.0       70.0
# 1        8.0         350.0       165.0  3693.0          11.5       70.0
# 2        8.0         318.0       150.0  3436.0          11.0       70.0
# 3        8.0         304.0       150.0  3433.0          12.0       70.0
# 4        8.0         302.0       140.0  3449.0          10.5       70.0
#
#    origin
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
sc=StandardScaler()

# %%
x_std=sc.fit_transform(x)

# %%
cov_matrix=np.cov(x_std.T)

# %%
eigenvalues,eigenvectors=np.linalg.eig(cov_matrix)

# %%
print("Eigan  values\n",eigenvalues)
# Out:
# Eigan  values
#  [4.5959209  0.94713238 0.75229805 0.48483455 0.1350502  0.03404428
#  0.06835189]

# %%
print("Eigan vectors\n",eigenvectors)
# Out:
# Eigan vectors
#  [[-4.39553380e-01 -1.16797425e-01  2.94844443e-02  2.36682946e-01
#    6.74773423e-01 -4.47629093e-01 -2.83852181e-01]
#  [-4.54620692e-01 -1.08469689e-01  2.62685287e-02  1.55722284e-01
#    1.84604274e-01  8.49784707e-01 -2.00524662e-02]
#  [-4.34765124e-01  1.59027687e-01  1.81747183e-01  1.35084509e-01
#   -6.29552888e-01 -1.19331872e-01 -5.69062989e-01]
#  [-4.32736260e-01 -2.05033337e-01  3.25484681e-04  3.31576461e-01
#   -2.88580887e-01 -2.38734722e-01  7.21446054e-01]
#  [ 2.98645792e-01 -4.87377664e-01 -5.33393252e-01  5.49459439e-01
#   -1.41541720e-01  3.80746770e-02 -2.55687168e-01]
#  [ 2.15960186e-01 -6.18657358e-01  7.51588948e-01  2.55071733e-02
#   -2.68512243e-02  1.29641514e-02 -6.47970072e-02]
#  [ 2.96653601e-01  5.35714756e-01  3.40608543e-01  6.99274401e-01
#    1.01149769e-01  6.81324661e-02  7.16530841e-02]]

# %%
eig_pairs=[(eigenvalues[index],eigenvectors[:,index])for index in range(len(eigenvalues))]

# %%
eig_pairs.sort()

# %%
eig_pairs.reverse()

# %%
print(eig_pairs)
# Out:
# [(4.595920898945803, array([-0.43955338, -0.45462069, -0.43476512, -0.43273626,  0.29864579,
#         0.21596019,  0.2966536 ])), (0.9471323761357473, array([-0.11679742, -0.10846969,  0.15902769, -0.20503334, -0.48737766,
#        -0.61865736,  0.53571476])), (0.7522980480022302, array([ 2.94844443e-02,  2.62685287e-02,  1.81747183e-01,  3.25484681e-04,
#        -5.33393252e-01,  7.51588948e-01,  3.40608543e-01])), (0.4848345455413271, array([0.23668295, 0.15572228, 0.13508451, 0.33157646, 0.54945944,
#        0.02550717, 0.6992744 ])), (0.13505020223850445, array([ 0.67477342,  0.18460427, -0.62955289, -0.28858089, -0.14154172,
#        -0.02685122,  0.10114977])), (0.06835189097588544, array([-0.28385218, -0.02005247, -0.56906299,  0.72144605, -0.25568717,
#        -0.06479701,  0.07165308])), (0.03404427997410317, array([-0.44762909,  0.84978471, -0.11933187, -0.23873472,  0.03807468,
#         0.01296415,  0.06813247]))]

# %%
eigvalues_sorted=[eig_pairs[index][0] for index in range(len(eigenvalues))]
eigvectors_sorted=[eig_pairs[index][1] for index in range(len(eigenvalues))]

# %%
p_reduce=np.array(eigvectors_sorted[0:7])

# %%
x_std_projected=np.dot(x_std,p_reduce.T)

# %%
proj_data=pd.DataFrame(x_std_projected)

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.8075917141582019

# %%
model.score(x_test,y_test)
# Out:
# 0.8489927930697778
